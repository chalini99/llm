# %%
#conda create -n rag_env python=3.10

# %%
#conda activate rag_env

# %%
#pip install torch==2.2.2
#pip install transformers==4.37.2
#pip install sentence-transformers==2.6.1
#pip install datasets==2.18.0
#pip install faiss-cpu

# %%
# !pip install torch==2.2.2

# %%
# !pip install transformers==4.37.2

# %%
# !pip install sentence-transformers==2.6.1

# %%
# !pip install datasets==2.18.0

# %%
# !pip install faiss-cpu

# %%
import transformers
import torch
import sentence_transformers

print(transformers.__version__)
print(torch.__version__)
print(sentence_transformers.__version__)
# Out:
# 4.37.2
# 2.2.2+cpu
# 2.6.1

# %%
# ============================================================
# RETRIEVAL AUGMENTED GENERATION (RAG) PIPELINE
# Using Hugging Face Transformers + FAISS + SentenceTransformers
# ============================================================

# ------------------------------------------------------------
# STEP 1: INSTALL REQUIRED LIBRARIES
# These libraries are required for building the RAG system
# ------------------------------------------------------------
# transformers -> provides pretrained language models
# datasets -> used to store and handle text datasets
# faiss-cpu -> efficient similarity search for retrieval
# sentence-transformers -> converts text into embeddings

# !pip install transformers datasets faiss-cpu sentence-transformers


# ------------------------------------------------------------
# STEP 2: IMPORT REQUIRED LIBRARIES
# ------------------------------------------------------------

from datasets import Dataset                     # Used to create dataset of documents
from sentence_transformers import SentenceTransformer  # Used to generate text embeddings
import faiss                                     # Used for vector similarity search
import numpy as np                               # Used for numerical vector operations
from transformers import pipeline                # Used to load text generation model


# ------------------------------------------------------------
# STEP 3: CREATE A KNOWLEDGE BASE (DOCUMENT COLLECTION)
# In RAG, we need external knowledge that can be retrieved
# ------------------------------------------------------------

documents = [
    "Artificial Intelligence is the simulation of human intelligence in machines.",
    "Machine Learning is a subset of artificial intelligence that enables systems to learn from data.",
    "Deep Learning uses neural networks with multiple hidden layers to learn complex patterns.",
    "Natural Language Processing allows computers to understand and process human language.",
    "Transformers are deep learning models that are widely used in modern NLP systems."
]

# Convert the document list into a Hugging Face dataset
dataset = Dataset.from_dict({"text": documents})

print("Dataset Created:")
print(dataset)


# ------------------------------------------------------------
# STEP 4: LOAD AN EMBEDDING MODEL
# Embeddings convert text into numerical vectors so that
# similarity between documents can be computed
# ------------------------------------------------------------

embedding_model = SentenceTransformer('all-MiniLM-L6-v2')


# ------------------------------------------------------------
# STEP 5: CONVERT DOCUMENTS INTO VECTOR EMBEDDINGS
# Each document will be represented as a numerical vector
# ------------------------------------------------------------

doc_embeddings = embedding_model.encode(documents)

# Convert embeddings to numpy array for FAISS compatibility
doc_embeddings = np.array(doc_embeddings)

print("\nShape of Document Embeddings:")
print(doc_embeddings.shape)


# ------------------------------------------------------------
# STEP 6: CREATE FAISS INDEX
# FAISS stores embeddings and performs fast similarity search
# ------------------------------------------------------------

dimension = doc_embeddings.shape[1]   # dimension of embedding vectors

# Create FAISS index using L2 distance
index = faiss.IndexFlatL2(dimension)

# Add document embeddings into FAISS index
index.add(doc_embeddings)

print("\nNumber of Documents Indexed:", index.ntotal)


# ------------------------------------------------------------
# STEP 7: DEFINE DOCUMENT RETRIEVAL FUNCTION
# This function finds the most relevant documents for a query
# ------------------------------------------------------------

def retrieve_documents(query, k=2):
    
    # Convert query into embedding vector
    query_embedding = embedding_model.encode([query])
    
    # Perform similarity search in FAISS
    distances, indices = index.search(np.array(query_embedding), k)
    
    # Retrieve corresponding documents
    retrieved_docs = [documents[i] for i in indices[0]]
    
    return retrieved_docs


# ------------------------------------------------------------
# STEP 8: LOAD TEXT GENERATION MODEL
# This model generates answers based on retrieved context
# ------------------------------------------------------------

#generator = pipeline(
  #  "text-generation",     # task type
   # model="gpt2",          # pretrained generation model
   # max_length=100         # maximum generated tokens
#)

generator = pipeline(
    "text2text-generation",
    model="google/flan-t5-base",
    max_length=150,
    min_length=20
)

# ------------------------------------------------------------
# STEP 9: BUILD THE COMPLETE RAG PIPELINE
# This combines retrieval + generation
# ------------------------------------------------------------

def rag_pipeline(query):
    
    # ---- Retrieval Step ----
    # Retrieve relevant documents for the query
    retrieved_docs = retrieve_documents(query)
    
    # Combine retrieved documents into a context
    context = " ".join(retrieved_docs)
    
    # ---- Prompt Construction ----
    # Combine context and query into a prompt
    prompt = f"Context: {context}\n\nQuestion: {query}\nAnswer:"
    
    # ---- Generation Step ----
    # Generate answer using language model
    result = generator(prompt)[0]["generated_text"]
    
    return result


# ------------------------------------------------------------
# STEP 10: TEST THE RAG SYSTEM
# Provide a query and generate answer
# ------------------------------------------------------------

query = "What is machine learning?"

response = rag_pipeline(query)

print("\n===============================")
print("USER QUESTION:")
print(query)

print("\nGENERATED ANSWER:")
print(response)
print("===============================")
# Out:
# Requirement already satisfied: transformers in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (4.37.2)
# Requirement already satisfied: datasets in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: faiss-cpu in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: sentence-transformers in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: filelock in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (23.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: Pillow in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2026.1.4)
# Requirement already satisfied: sympy in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.2.1)
# Dataset Created:
# Dataset({
#     features: ['text'],
#     num_rows: 5
# })
# C:\Users\qawsar.gulzar\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Shape of Document Embeddings:
# (5, 384)
#
# Number of Documents Indexed: 5
# C:\Users\qawsar.gulzar\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ===============================
# USER QUESTION:
# What is machine learning?
#
# GENERATED ANSWER:
# enables systems to learn from data. Artificial Intelligence is the simulation of human intelligence in machines.
# ===============================

# %%
# ============================================================
# RETRIEVAL AUGMENTED GENERATION (RAG) PIPELINE
# Using Hugging Face Transformers + FAISS + SentenceTransformers
# ============================================================

# ------------------------------------------------------------
# STEP 1: INSTALL REQUIRED LIBRARIES
# These libraries are required for building the RAG system
# ------------------------------------------------------------
# transformers -> provides pretrained language models
# datasets -> used to store and handle text datasets
# faiss-cpu -> efficient similarity search for retrieval
# sentence-transformers -> converts text into embeddings

# !pip install transformers datasets faiss-cpu sentence-transformers


# ------------------------------------------------------------
# STEP 2: IMPORT REQUIRED LIBRARIES
# ------------------------------------------------------------

from datasets import Dataset                     # Used to create dataset of documents
from sentence_transformers import SentenceTransformer  # Used to generate text embeddings
import faiss                                     # Used for vector similarity search
import numpy as np                               # Used for numerical vector operations
from transformers import pipeline                # Used to load text generation model


# ------------------------------------------------------------
# STEP 3: CREATE A KNOWLEDGE BASE (DOCUMENT COLLECTION)
# In RAG, we need external knowledge that can be retrieved
# ------------------------------------------------------------

documents = [
    "Artificial Intelligence is the simulation of human intelligence in machines.",
    "Machine Learning is a subset of artificial intelligence that enables systems to learn from data.",
    "Deep Learning uses neural networks with multiple hidden layers to learn complex patterns.",
    "Natural Language Processing allows computers to understand and process human language.",
    "Transformers are deep learning models that are widely used in modern NLP systems."
]

# Convert the document list into a Hugging Face dataset
dataset = Dataset.from_dict({"text": documents})

print("Dataset Created:")
print(dataset)


# ------------------------------------------------------------
# STEP 4: LOAD AN EMBEDDING MODEL
# Embeddings convert text into numerical vectors so that
# similarity between documents can be computed
# ------------------------------------------------------------

embedding_model = SentenceTransformer('all-MiniLM-L6-v2')


# ------------------------------------------------------------
# STEP 5: CONVERT DOCUMENTS INTO VECTOR EMBEDDINGS
# Each document will be represented as a numerical vector
# ------------------------------------------------------------

doc_embeddings = embedding_model.encode(documents)

# Convert embeddings to numpy array for FAISS compatibility
doc_embeddings = np.array(doc_embeddings)

print("\nShape of Document Embeddings:")
print(doc_embeddings.shape)


# ------------------------------------------------------------
# STEP 6: CREATE FAISS INDEX
# FAISS stores embeddings and performs fast similarity search
# ------------------------------------------------------------

dimension = doc_embeddings.shape[1]   # dimension of embedding vectors

# Create FAISS index using L2 distance
index = faiss.IndexFlatL2(dimension)

# Add document embeddings into FAISS index
index.add(doc_embeddings)

print("\nNumber of Documents Indexed:", index.ntotal)


# ------------------------------------------------------------
# STEP 7: DEFINE DOCUMENT RETRIEVAL FUNCTION
# This function finds the most relevant documents for a query
# ------------------------------------------------------------

def retrieve_documents(query, k=2):
    
    # Convert query into embedding vector
    query_embedding = embedding_model.encode([query])
    
    # Perform similarity search in FAISS
    distances, indices = index.search(np.array(query_embedding), k)
    
    # Retrieve corresponding documents
    retrieved_docs = [documents[i] for i in indices[0]]
    
    return retrieved_docs


# ------------------------------------------------------------
# STEP 8: LOAD TEXT GENERATION MODEL
# This model generates answers based on retrieved context
# ------------------------------------------------------------

generator = pipeline(
   "text-generation",     # task type
    model="gpt2",          # pretrained generation model
    max_length=100         # maximum generated tokens
)


# ------------------------------------------------------------
# STEP 9: BUILD THE COMPLETE RAG PIPELINE
# This combines retrieval + generation
# ------------------------------------------------------------

def rag_pipeline(query):
    
    # ---- Retrieval Step ----
    # Retrieve relevant documents for the query
    retrieved_docs = retrieve_documents(query)
    
    # Combine retrieved documents into a context
    context = " ".join(retrieved_docs)
    
    # ---- Prompt Construction ----
    # Combine context and query into a prompt
    prompt = f"Context: {context}\n\nQuestion: {query}\nAnswer:"
    
    # ---- Generation Step ----
    # Generate answer using language model
    result = generator(prompt)[0]["generated_text"]
    
    return result


# ------------------------------------------------------------
# STEP 10: TEST THE RAG SYSTEM
# Provide a query and generate answer
# ------------------------------------------------------------

query = "What is machine learning?"

response = rag_pipeline(query)

print("\n===============================")
print("USER QUESTION:")
print(query)

print("\nGENERATED ANSWER:")
print(response)
print("===============================")
# Out:
# Requirement already satisfied: transformers in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (4.37.2)
# Requirement already satisfied: datasets in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: faiss-cpu in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: sentence-transformers in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: filelock in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (23.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: Pillow in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2026.1.4)
# Requirement already satisfied: sympy in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\qawsar.gulzar\appdata\local\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.2.1)
# Dataset Created:
# Dataset({
#     features: ['text'],
#     num_rows: 5
# })
#
# Shape of Document Embeddings:
# (5, 384)
#
# Number of Documents Indexed: 5
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ===============================
# USER QUESTION:
# What is machine learning?
#
# GENERATED ANSWER:
# Context: Machine Learning is a subset of artificial intelligence that enables systems to learn from data. Artificial Intelligence is the simulation of human intelligence in machines.
#
# Question: What is machine learning?
# Answer: For more than 30 generations, AI (AI for short) has led to the emergence of the world's most advanced systems. In many senses, AI has been regarded as a way to create human-like things and replace natural systems. It can now be seen as either the future of our understanding
# ===============================
